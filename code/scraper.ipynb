# %% [markdown]
# # Scraping Notebook
#
# Tasks:
#
# 1. Identify hastags(manual)
#
# 2. Use Twitter API for image scraping (stored in "...data/raw/")
#
# 3. Pre-processing = Remove duplicates

# %% [markdown]
# **Hashtags** -
# \#infographics
# \#infographic

# %% [markdown]
# # TwitterAPI - python script for scraping twitter
#
# [Github repository](https://github.com/geduldig/TwitterGeoPics.git)

# %%
#!git clone https://github.com/geduldig/TwitterGeoPics.git

# %% [markdown]
# # Directory Structure
#
# *Note* - TwitterAuth credentials to be changed according to personal user account
#
# 1. Folder to store scraped images (infographics_dataset_collection/data/raw)
# 2. File for twitter authentication credentials (infographics_dataset_collection/twitter_auth.conf)

# %%
ENV_PARENT_DIR="/content/gdrive/My\ Drive/projects/infographics_dataset_collection"
ENV_DATA_DIR=ENV_PARENT_DIR+"/data/raw/"
ENV_AUTH_FILE=ENV_PARENT_DIR+"/twitter_auth.conf"
ENV_SEARCH_TERM="infographic"

# %% [markdown]
# # Requirements

# %%
# !pip install Fridge
# !pip install tweepy
# !pip install pygeocoder
# !pip install tzwhere
# !pip install TwitterAPI

# %% [markdown]
# # Mounting Google Drive for Project Structure
#
# 1. Notebooks for scraping and classification (code/)
# 2. Data including raw and processed images (data/)
# 3. Saved trained models (models/)
# 4. Final deliverable (output/)

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# # Running Scraper
#
# ## args
#
# 1. -oauth = file containing twitter credentials
# 2. -words = search terms
# 3. -photo_dir = raw data directory

# %%
# %cd /content/gdrive/My Drive/projects/infographics_dataset_collection/TwitterGeoPics
# Out:
# /content/gdrive/My Drive/projects/infographics_dataset_collection/TwitterGeoPics

# %%
# !python -u -m TwitterGeoPics.SearchOldTweets -oauth $ENV_AUTH_FILE -words $ENV_SEARCH_TERM -photo_dir $ENV_DATA_DIR
# Out:
# DiscountedProd1: We are team of creative designers. Our mission is to deliver best service for our clients and to acquire their ulti… https://t.co/qX4SnUSBbv
# Sun May 10 01:55:02 +0000 2020
#
# gowshick_g: RT @LMKMovieManiac: North Chennai @Suriya_offl Fans Club Members have been doing grt charity - relief work during this #Corona crisis
#
# Kud…
# Sun May 10 01:54:14 +0000 2020
#
# DiscountedProd1: We are a team of young and dynamic graphic designers with a very modern outlook... We are into creative Graphic and… https://t.co/2r15pWdoDb
# Sun May 10 01:54:02 +0000 2020
#
# methgoode666: wtf is an infographic 💀💀
# Sun May 10 01:53:59 +0000 2020
#
# Neuroglyph: RT @simongerman600: Depending on the projection you use to display the spherical earth onto a flat #map you distort areas a bit. This wonde…
# Sun May 10 01:53:35 +0000 2020
#
# TheRedBunny0901: RT @longtunman: ความแตกต่างของ TWG กับ TWININGS
#
# ติดตามความรู้ธุรกิจ และไลฟ์สไตล์สำหรับผู้หญิงได้ที่ https://t.co/ctBqHklf6O
#
# ...

# %% [markdown]
# # TODO- Add script to scrape user accounts- @IGJournal, @info_graphic

# %% [markdown]
# # Pre-processing
#
# 1. Remove duplicates (reduced count from 334 -> 188)

# %%
# !pip install imagecleaner

# %%
# !image-cleaner $ENV_DATA_DIR
